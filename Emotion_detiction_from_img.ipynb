# %%
# !pip install deepface

# %%
# !pip install opencv-python matplotlib

# %% [markdown]
# import moduls

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Read img (sad, happy, angry )

# %%
img1 = cv2.imread('./img/happy.jpg') #happy img
img2 = cv2.imread('./img/angry.jpg') #angry img
img3 = cv2.imread('./img/sad.jpg') #sad img
plt.imshow(img1[:, :, ::-1])
plt.show()

# %%
result = DeepFace.analyze(img3, actions=["emotion"])

# %%
print(result)
# Out:
# [{'emotion': {'angry': 0.22518027108162642, 'disgust': 5.290731763807344e-06, 'fear': 67.32059717178345, 'happy': 0.004771600652020425, 'sad': 29.556217789649963, 'surprise': 0.00014598534789911355, 'neutral': 2.8930826112627983}, 'dominant_emotion': 'fear', 'region': {'x': 169, 'y': 47, 'w': 879, 'h': 879}, 'face_confidence': 4.514612152648624}]
